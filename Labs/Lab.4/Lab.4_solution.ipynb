# %% [markdown]
# ## Name: **Muhammad Anas**

# %% [markdown]
# # Lab 4- Object Oriented Programming
#
# For all of the exercises below, make sure you provide tests of your solutions.

# %% [markdown]
# 1. Write a "counter" class that can be incremented up to a specified maximum value, will print an error if an attempt is made to increment beyond that value, and allows reseting the counter.

# %%
class Counter:
    def __init__(self, max_val):
        self.max_val = max_val
        self.count = 0

    def increment(self):
        if self.count < self.max_val:
            self.count += 1
        else:
            print("Can't go beyond the limit.")
    
    def reset(self):
        self.count = 0

    def ret(self):
        return self.count

# %% [markdown]
# 2. Copy and paste your solution to question 1 and modify it so that all the data held by the counter is private. Implement functions to check the value of the counter, check the maximum value, and check if the counter is at the maximum.

# %%
class Counter:
    def __init__(self, max_val):
        self.__max_val = max_val
        self.__count = 0

    def increment(self):
        if self.__count < self.__max_val:
            self.__count += 1
        else:
            print("Can't go beyond the limit.")
    
    def reset(self):
        self.__count = 0

    def ret(self):
        return self.__count

# %% [markdown]
# 3. Implement a class to represent a rectangle, holding the length, width, and $x$ and $y$ coordinates of a corner of the object. Implement functions that compute the area and perimeter of the rectangle. Make all data members private and privide accessors to retrieve values of data members.

# %%
class Rectangle:
    def __init__(self, length, width, x, y):
        self.__length = length
        self.__width = width
        self.__x = x
        self.__y = y

    def get_length(self):
        return self.__length

    def get_width(self):
        return self.__width

    def get_x(self):
        return self.__x

    def get_y(self):
        return self.__y

    def area(self):
        return self.__length * self.__width

    def perimeter(self):
        return 2 * (self.__length + self.__width)

# %%
rectangle = Rectangle(10, 5, 0, 0)
print(f"Length: {rectangle.get_length()}")
print(f"Width: {rectangle.get_width()}")
print(f"X-coordinate: {rectangle.get_x()}")
print(f"Y-coordinate: {rectangle.get_y()}")
print(f"Area: {rectangle.area()}")
print(f"Perimeter: {rectangle.perimeter()}")
# Out:
# Length: 10
# Width: 5
# X-coordinate: 0
# Y-coordinate: 0
# Area: 50
# Perimeter: 30

# %% [markdown]
# 4. Implement a class to represent a circle, holding the radius and $x$ and $y$ coordinates of center of the object. Implement functions that compute the area and perimeter of the circle. Make all data members private and privide accessors to retrieve values of data members.

# %%
class Circle:
    def __init__(self, radius, x, y):
        self.__radius = radius
        self.__x = x
        self.__y = y

    def get_radius(self):
        return self.__radius

    def get_x(self):
        return self.__x

    def get_y(self):
        return self.__y

    def area(self):
        return 3.14159 * (self.__radius ** 2)

    ##Circumference == Perimeter
    def perimeter(self):
        return 2 * 3.14159 * self.__radius

# %%
circle = Circle(7, 0, 0)
print(f"Radius: {circle.get_radius()}")
print(f"X-coordinate: {circle.get_x()}")
print(f"Y-coordinate: {circle.get_y()}")
print(f"Area: {circle.area()}")
print(f"perimeter: {circle.perimeter()}")
# Out:
# Radius: 7
# X-coordinate: 0
# Y-coordinate: 0
# Area: 153.93791
# perimeter: 43.98226

# %% [markdown]
# 5. Implement a common base class for the classes implemented in 3 and 4 above which implements all common methods as not implemented functions (virtual). Re-implement your regtangle and circule classes to inherit from the base class and overload the functions accordingly.

# %%
class Shape():
    def area(self):
        pass
    
    def perimeter(self):
        pass
    
    def get_x(self):
        pass

    def get_y(self):
        pass

### inherited class for circle
class Circle(Shape):
    def __init__(self, radius, x, y):

        self.__radius = radius
        self.__x = x
        self.__y = y

    def get_radius(self):
        return self.__radius

    def get_x(self):
        return self.__x

    def get_y(self):
        return self.__y

    def area(self):
        pi = 3.14159
        return pi * (self.__radius ** 2)

    def perimeter(self):
        pi = 3.14159
        return 2 * pi * self.__radius

### inherited class for rectangle
class Rectangle(Shape):
    def __init__(self, length, width, x, y):

        self.__length = length
        self.__width = width
        self.__x = x
        self.__y = y

    def get_length(self):
        return self.__length

    def get_width(self):
        return self.__width

    def get_x(self):
        return self.__x

    def get_y(self):
        return self.__y

    def area(self):
        return self.__length * self.__width

    def perimeter(self):
        return 2 * (self.__length + self.__width)

# %%
print("Circle:")
print(f"Radius: {circle.get_radius()}")
print(f"X-coordinate: {circle.get_x()}")
print(f"Y-coordinate: {circle.get_y()}")
print(f"Area: {circle.area()}")
print(f"Circumference: {circle.perimeter()}")

print("\nRectangle:")
print(f"Length: {rectangle.get_length()}")
print(f"Width: {rectangle.get_width()}")
print(f"X-coordinate: {rectangle.get_x()}")
print(f"Y-coordinate: {rectangle.get_y()}")
print(f"Area: {rectangle.area()}")
print(f"Perimeter: {rectangle.perimeter()}")
# Out:
# Circle:
# Radius: 7
# X-coordinate: 0
# Y-coordinate: 0
# Area: 153.93791
# Circumference: 43.98226
#
# Rectangle:
# Length: 10
# Width: 5
# X-coordinate: 0
# Y-coordinate: 0
# Area: 50
# Perimeter: 30

# %% [markdown]
# 6. Implement a triangle class analogous to the rectangle and circle in question 5.

# %%
class Triangle:
    def __init__(self, side_a, side_b, side_c, x1, y1, x2, y2, x3, y3):
        self.__side_a = side_a
        self.__side_b = side_b
        self.__side_c = side_c
        self.__x1 = x1
        self.__y1 = y1
        self.__x2 = x2
        self.__y2 = y2
        self.__x3 = x3
        self.__y3 = y3

    def get_side_a(self):
        return self.__side_a

    def get_side_b(self):
        return self.__side_b

    def get_side_c(self):
        return self.__side_c

    def get_coordinates(self):
        return (self.__x1, self.__y1), (self.__x2, self.__y2), (self.__x3, self.__y3)

    def perimeter(self):
        return self.__side_a + self.__side_b + self.__side_c

    def area(self):
        s = self.perimeter() / 2  
        return (s * (s - self.__side_a) * (s - self.__side_b) * (s - self.__side_c)) ** 0.5

# %%
triangle = Triangle(3, 4, 5, 0, 0, 3, 0, 0, 4)

print("Triangle:")
print(f"Side A: {triangle.get_side_a()}")
print(f"Side B: {triangle.get_side_b()}")
print(f"Side C: {triangle.get_side_c()}")
print(f"Coordinates of vertices: {triangle.get_coordinates()}")
print(f"Area: {triangle.area()}")
print(f"Perimeter: {triangle.perimeter()}")
# Out:
# Triangle:
# Side A: 3
# Side B: 4
# Side C: 5
# Coordinates of vertices: ((0, 0), (3, 0), (0, 4))
# Area: 6.0
# Perimeter: 12

# %% [markdown]
# 7. Add a function to the object classes, including the base, that returns a list of up to 16 pairs of  $x$ and $y$ points on the parameter of the object.

# %%
import math

class Shape():
    def area(self):
        pass

    def perimeter(self):
        pass

    def get_points_on_perimeter(self):
        pass

class Circle(Shape):
    def __init__(self, radius, x, y):
        self.__radius = radius
        self.__x = x
        self.__y = y

    def get_radius(self):
        return self.__radius

    def get_x(self):
        return self.__x

    def get_y(self):
        return self.__y

    def area(self):
        pi = 3.14159
        return pi * (self.__radius ** 2)

    def perimeter(self):
        pi = 3.14159
        return 2 * pi * self.__radius

    def get_points_on_perimeter(self):
        points = []
        pi = 3.14159
        for i in range(16):
            theta = 2 * pi * i / 16
            x = self.__x + self.__radius * math.cos(theta)
            y = self.__y + self.__radius * math.sin(theta)
            points.append((x, y))
        return points

class Rectangle(Shape):
    def __init__(self, length, width, x, y):
        self.__length = length
        self.__width = width
        self.__x = x
        self.__y = y

    def get_length(self):
        return self.__length

    def get_width(self):
        return self.__width

    def get_x(self):
        return self.__x

    def get_y(self):
        return self.__y

    def area(self):
        return self.__length * self.__width

    def perimeter(self):
        return 2 * (self.__length + self.__width)

    def get_points_on_perimeter(self):
        points = []
        for i in range(4):
            if i == 0:  
                for j in range(4):
                    x = self.__x + j * (self.__length / 3)
                    y = self.__y
                    points.append((x, y))
            elif i == 1:  
                for j in range(4):
                    x = self.__x + self.__length
                    y = self.__y + j * (self.__width / 3)
                    points.append((x, y))
            elif i == 2:
                for j in range(4):
                    x = self.__x + (3 - j) * (self.__length / 3)
                    y = self.__y + self.__width
                    points.append((x, y))
            elif i == 3: 
                for j in range(4):
                    x = self.__x
                    y = self.__y + (3 - j) * (self.__width / 3)
                    points.append((x, y))
        return points

# %%
circle = Circle(7, 0, 0)
rectangle = Rectangle(10, 5, 0, 0)

print("Points on the perimeter of the circle:")
for point in circle.get_points_on_perimeter():
    print(point)

print("\nPoints on the perimeter of the rectangle:")
for point in rectangle.get_points_on_perimeter():
    print(point)
# Out:
# Points on the perimeter of the circle:
# (7.0, 0.0)
# (6.467157616127896, 2.6787818814078452)
# (4.949750751954584, 4.949744184654903)
# (2.678790461997209, 6.467154061928073)
# (9.28756427674273e-06, 6.999999999993839)
# (-2.6787733008137673, 6.4671611703163325)
# (-4.949737617346508, 4.949757319245553)
# (-6.467150507716866, 2.678799042581857)
# (-6.999999999975355, 1.857512855346911e-05)
# (-6.467164724493385, -2.6787647202149727)
# (-4.949763886527804, -4.949731050029402)
# (-2.6788076231617857, -6.467146953494276)
# (-2.7862692833271418e-05, -6.9999999999445475)
# (2.6787561396114596, -6.467168278659054)
# (4.949724482703579, -4.949770453801347)
# (6.4671433992603, -2.678816203737005)
#
# Points on the perimeter of the rectangle:
# (0.0, 0)
# (3.3333333333333335, 0)
# (6.666666666666667, 0)
# (10.0, 0)
# (10, 0.0)
# (10, 1.6666666666666667)
# (10, 3.3333333333333335)
# (10, 5.0)
# (10.0, 5)
# (6.666666666666667, 5)
# (3.3333333333333335, 5)
# (0.0, 5)
# (0, 5.0)
# ...

# %% [markdown]
# 8. Add a function to the object classes, including the base, that tests if a given set of $x$ and $y$ coordinates are inside of the object. You'll have to think through how to determine if a set of coordinates are inside an object for each object type.

# %%
class Shape():
    def area(self):
        pass

    def perimeter(self):
        pass

    def get_points_on_perimeter(self):
        pass

    def is_inside(self, x, y):
        pass

# Circle Class that inherits from Shape
class Circle(Shape):
    def __init__(self, radius, x, y):
        self.__radius = radius
        self.__x = x
        self.__y = y

    def get_radius(self):
        return self.__radius

    def get_x(self):
        return self.__x

    def get_y(self):
        return self.__y

    def area(self):
        pi = 3.14159
        return pi * (self.__radius ** 2)

    def perimeter(self):
        pi = 3.14159
        return 2 * pi * self.__radius

    def get_points_on_perimeter(self):
        points = []
        pi = 3.14159
        for i in range(16):
            theta = 2 * pi * i / 16
            x = self.__x + self.__radius * math.cos(theta)
            y = self.__y + self.__radius * math.sin(theta)
            points.append((x, y))
        return points

    def is_inside(self, x, y):
        distance_squared = (x - self.__x)**2 + (y - self.__y)**2
        return distance_squared <= self.__radius**2

# Rectangle Class that inherits from Shape
class Rectangle(Shape):
    def __init__(self, length, width, x, y):
        self.__length = length
        self.__width = width
        self.__x = x
        self.__y = y

    def get_length(self):
        return self.__length

    def get_width(self):
        return self.__width

    def get_x(self):
        return self.__x

    def get_y(self):
        return self.__y

    def area(self):
        return self.__length * self.__width

    def perimeter(self):
        return 2 * (self.__length + self.__width)

    def get_points_on_perimeter(self):
        points = []

        for i in range(4):

            if i == 0:  
                for j in range(4):
                    x = self.__x + j * (self.__length / 3)
                    y = self.__y
                    points.append((x, y))
            elif i == 1:
                for j in range(4):
                    x = self.__x + self.__length
                    y = self.__y + j * (self.__width / 3)
                    points.append((x, y))
            elif i == 2: 
                for j in range(4):
                    x = self.__x + (3 - j) * (self.__length / 3)
                    y = self.__y + self.__width
                    points.append((x, y))
            elif i == 3: 
                for j in range(4):
                    x = self.__x
                    y = self.__y + (3 - j) * (self.__width / 3)
                    points.append((x, y))
        return points

    def is_inside(self, x, y):
        return self.__x <= x <= self.__x + self.__length and self.__y <= y <= self.__y + self.__width

# %%
circle = Circle(7, 0, 0)
rectangle = Rectangle(10, 5, 0, 0)

print(f"Point (3, 4) inside circle: {circle.is_inside(3, 4)}")
print(f"Point (7, 0) inside circle: {circle.is_inside(7, 0)}")

print(f"Point (3, 4) inside rectangle: {rectangle.is_inside(3, 4)}")
print(f"Point (12, 3) inside rectangle: {rectangle.is_inside(12, 3)}")
# Out:
# Point (3, 4) inside circle: True
# Point (7, 0) inside circle: True
# Point (3, 4) inside rectangle: True
# Point (12, 3) inside rectangle: False

# %% [markdown]
# 9. Add a function in the base class of the object classes that returns true/false testing that the object overlaps with another object.

# %%
import math

class Shape():

    def area(self):
        pass

    def perimeter(self):
        pass

    def get_points_on_perimeter(self):
        pass

    def is_inside(self, x, y):
        pass

    def overlaps(self, other):
        pass

# Circle Class that inherits from Shape
class Circle(Shape):
    def __init__(self, radius, x, y):
        self.__radius = radius
        self.__x = x
        self.__y = y

    def get_radius(self):
        return self.__radius

    def get_x(self):
        return self.__x

    def get_y(self):
        return self.__y

    def area(self):
        pi = 3.14159
        return pi * (self.__radius ** 2)


    def perimeter(self):
        pi = 3.14159
        return 2 * pi * self.__radius

    def get_points_on_perimeter(self):
        points = []
        pi = 3.14159
        for i in range(16):
            theta = 2 * pi * i / 16
            x = self.__x + self.__radius * math.cos(theta)
            y = self.__y + self.__radius * math.sin(theta)
            points.append((x, y))
        return points


    def is_inside(self, x, y):
        distance_squared = (x - self.__x)**2 + (y - self.__y)**2
        return distance_squared <= self.__radius**2

    def overlaps(self, other):
        if isinstance(other, Circle):
            distance_between_centers = math.sqrt((self.__x - other.get_x())**2 + (self.__y - other.get_y())**2)
            return distance_between_centers <= (self.__radius + other.get_radius())
        return False 

# Rectangle Class that inherits from Shape
class Rectangle(Shape):
    def __init__(self, length, width, x, y):
        self.__length = length
        self.__width = width
        self.__x = x
        self.__y = y

    def get_length(self):
        return self.__length

    def get_width(self):
        return self.__width

    def get_x(self):
        return self.__x

    def get_y(self):
        return self.__y

    def area(self):
        return self.__length * self.__width

    def perimeter(self):
        return 2 * (self.__length + self.__width)

    def get_points_on_perimeter(self):
        points = []
        for i in range(4):
            if i == 0:  
                for j in range(4):
                    x = self.__x + j * (self.__length / 3)
                    y = self.__y
                    points.append((x, y))
            elif i == 1:
                for j in range(4):
                    x = self.__x + self.__length
                    y = self.__y + j * (self.__width / 3)
                    points.append((x, y))
            elif i == 2:
                for j in range(4):
                    x = self.__x + (3 - j) * (self.__length / 3)
                    y = self.__y + self.__width
                    points.append((x, y))
            elif i == 3:
                for j in range(4):
                    x = self.__x
                    y = self.__y + (3 - j) * (self.__width / 3)
                    points.append((x, y))
        return points

    def is_inside(self, x, y):
        return self.__x <= x <= self.__x + self.__length and self.__y <= y <= self.__y + self.__width

    def overlaps(self, other):
        if isinstance(other, Rectangle):
            if self.__x + self.__length < other.get_x() or other.get_x() + other.get_length() < self.__x:
                return False
            if self.__y + self.__width < other.get_y() or other.get_y() + other.get_width() < self.__y:
                return False
            return True
        return False

# %%
circle1 = Circle(7, 0, 0)
circle2 = Circle(5, 3, 3)

rectangle1 = Rectangle(10, 5, 0, 0)
rectangle2 = Rectangle(5, 3, 3, 3)

# Test if the shapes overlap
print(f"Circle 1 overlaps with Circle 2: {circle1.overlaps(circle2)}")
print(f"Rectangle 1 overlaps with Rectangle 2: {rectangle1.overlaps(rectangle2)}")
# Out:
# Circle 1 overlaps with Circle 2: True
# Rectangle 1 overlaps with Rectangle 2: True

# %% [markdown]
# 10. Copy the `Canvas` class from lecture to in a python file creating a `paint` module. Copy your classes from above into the module and implement paint functions. Implement a `CompoundShape` class. Create a simple drawing demonstrating that all of your classes are working.

# %%
from Paint import Canvas, Rectangle, Circle, CompoundShape

canvas = Canvas(20, 10)

rectangle = Rectangle(3, 3, 6, 4)
circle = Circle(10, 5, 3)

compound = CompoundShape()
compound.add_shape(rectangle)
compound.add_shape(circle)

compound.draw(canvas)

canvas.display()
# Out:
# ***************
# ***************
# ***************
# ****************
# ***************
# ***************
# ***************
# ***************
# **************
# **************

# %% [markdown]
# 11. Create a `RasterDrawing` class. Demonstrate that you can create a drawing made of several shapes, paint the drawing, modify the drawing, and paint it again.

# %%
class RasterDrawing:
    def __init__(self):
        self.shapes = []

    def add_shape(self, shape):
        self.shapes.append(shape)

    def remove_shape(self, shape):
        if shape in self.shapes:
            self.shapes.remove(shape)

    def modify_shape(self, old_shape, new_shape):
        if old_shape in self.shapes:
            index = self.shapes.index(old_shape)
            self.shapes[index] = new_shape

    def paint(self, canvas):
        canvas.clear_canvas()
        for shape in self.shapes:
            shape.draw(canvas)

    def display(self, canvas):
        self.paint(canvas)
        canvas.display()

# %%
canvas = Canvas(20, 10)

rectangle = Rectangle(6, 4, 3, 3)
circle = Circle(3, 10, 5)

drawing = RasterDrawing()
drawing.add_shape(rectangle)
drawing.add_shape(circle)

print("Initial drawing:")
drawing.display(canvas)

new_rectangle = Rectangle(5, 3, 5, 2)
drawing.remove_shape(circle)
drawing.add_shape(new_rectangle)

print("\nModified drawing:")
drawing.display(canvas)
# Out:
# Initial drawing:
#
#
#           *
#    **** *****
#    *  * *****
#    *  ********
#    *  * *****
#    *  * *****
#    ****   *
#
#
# Modified drawing:
#
#
#      ***
#    *****
#    * ***
#    * ***
#    * ***
#    *  *
#    ****

# %% [markdown]
# 12. Implement the ability to load/save raster drawings and demonstate that your method works. One way to implement this ability:
#
#    * Overload `__repr__` functions of all objects to return strings of the python code that would construct the object.
#
#    * In the save method of raster drawing class, store the representations into the file.
#    * Write a loader function that reads the file and uses `eval` to instantiate the object.
#
# For example:

# %%
class foo:
    def __init__(self,a,b=None):
        self.a=a
        self.b=b
        
    def __repr__(self):
        return "foo("+repr(self.a)+","+repr(self.b)+")"
    
    def save(self,filename):
        f=open(filename,"w")
        f.write(self.__repr__())
        f.close()
        
   
def foo_loader(filename):
    f=open(filename,"r")
    tmp=eval(f.read())
    f.close()
    return tmp

# %%
# Test
print(repr(foo(1,"hello")))
# Out:
# foo(1,'hello')

# %%
# Create an object and save it
ff=foo(1,"hello")
ff.save("Test.foo")

# %%
# Check contents of the saved file
# !cat Test.foo
# Out:
# foo(1,'hello')

# %%
# Load the object
ff_reloaded=foo_loader("Test.foo")
ff_reloaded
# Out:
# foo(1,'hello')

# %%
class RasterDrawing:
    def __init__(self):
        self.shapes = []

    def add_shape(self, shape):
        self.shapes.append(shape)

    def remove_shape(self, shape):
        if shape in self.shapes:
            self.shapes.remove(shape)

    def modify_shape(self, old_shape, new_shape):
        if old_shape in self.shapes:
            index = self.shapes.index(old_shape)
            self.shapes[index] = new_shape

    def paint(self, canvas):
        canvas.clear_canvas()
        for shape in self.shapes:
            shape.draw(canvas)

    def display(self, canvas):
        self.paint(canvas)
        canvas.display()

    def save(self, filename):
        with open(filename, 'w') as f:
            for shape in self.shapes:
                f.write(f"{repr(shape)}\n")

    def load(self, filename):
        with open(filename, 'r') as f:
            shape_strings = f.readlines()
            for shape_str in shape_strings:
                shape = eval(shape_str.strip())
                self.shapes.append(shape)
